# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.read_csv('A_stock_trends_17_21.csv')
# Out:
#             date      open      high       low     close     volume
# 0     03/01/2017   27.3275   27.4526   27.0821   27.4101  115127460
# 1     04/01/2017   27.3393   27.4951   27.3157   27.3795   84472464
# 2     05/01/2017   27.3559   27.5787   27.3299   27.5187   88774348
# 3     06/01/2017   27.5588   27.8845   27.4857   27.8255  127007600
# 4     09/01/2017   27.8349   28.1842   27.8326   28.0803  134247792
# ...          ...       ...       ...       ...       ...        ...
# 1115  09/06/2021  127.2100  127.7500  126.5200  127.1300   55584187
# 1116  10/06/2021  127.0200  128.1900  125.9400  126.1100   70606505
# 1117  11/06/2021  126.5300  127.4400  126.1000  127.3500   52839952
# 1118  14/06/2021  127.8200  130.5400  127.0700  130.4800   96906490
# 1119  15/06/2021  129.9400  130.6000  129.3900  129.6400   60771136
#
# [1120 rows x 6 columns]

# %%
apple=pd.read_csv('A_stock_trends_17_21.csv')
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
apple['close'].mean()
# Out:
# 64.13527946428565

# %%
apple['close'].median()
# Out:
# 49.8519

# %%
apple['close'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
apple['close'].plot(kind='density', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax = apple['close'].plot(kind='density', figsize=(14,6)) 
ax.axvline(apple['close'].mean(), color='red')
ax.axvline(apple['close'].median(), color='green')

# %%
apple['average_price'] = (apple['high'] + apple['low']) /2

apple['average_price'].head()
# Out:
# 0    27.26735
# 1    27.40540
# 2    27.45430
# 3    27.68510
# 4    28.00840
# Name: average_price, dtype: float64

# %%
apple['revenue_blns'] = apple['close'] * apple['volume']/10**6

apple['revenue_blns'].head()
# Out:
# 0    3155.655191
# 1    2312.813828
# 2    2442.954650
# 3    3534.049974
# 4    3769.718274
# Name: revenue_blns, dtype: float64

# %%
(apple['revenue_blns'] != apple['revenue_blns']).sum()
# Out:
# 0

# %%
apple
# Out:
#             date      open      high       low     close     volume  \
# 0     03/01/2017   27.3275   27.4526   27.0821   27.4101  115127460
# 1     04/01/2017   27.3393   27.4951   27.3157   27.3795   84472464
# 2     05/01/2017   27.3559   27.5787   27.3299   27.5187   88774348
# 3     06/01/2017   27.5588   27.8845   27.4857   27.8255  127007600
# 4     09/01/2017   27.8349   28.1842   27.8326   28.0803  134247792
# ...          ...       ...       ...       ...       ...        ...
# 1115  09/06/2021  127.2100  127.7500  126.5200  127.1300   55584187
# 1116  10/06/2021  127.0200  128.1900  125.9400  126.1100   70606505
# 1117  11/06/2021  126.5300  127.4400  126.1000  127.3500   52839952
# 1118  14/06/2021  127.8200  130.5400  127.0700  130.4800   96906490
# 1119  15/06/2021  129.9400  130.6000  129.3900  129.6400   60771136
#
#       average_price  revenue_blns
# 0          27.26735   3155.655191
# 1          27.40540   2312.813828
# 2          27.45430   2442.954650
# ...

# %%
apple.describe()
# Out:
#               open         high          low        close        volume  \
# count  1120.000000  1120.000000  1120.000000  1120.000000  1.120000e+03
# mean     64.107069    64.814452    63.401446    64.135279  1.254200e+08
# std      32.579647    33.006630    32.049636    32.530140  5.693605e+07
# min      27.327500    27.452600    27.082100    27.379500  4.544818e+07
# 25%      40.804700    41.199125    40.403000    40.705350  8.708457e+07
# 50%      49.741350    50.162700    49.422700    49.851900  1.097285e+08
# 75%      78.904550    79.647450    78.381475    78.960450  1.461443e+08
# max     143.143200   144.628500   140.920300   142.704600  4.479402e+08
#
#        average_price  revenue_blns
# count    1120.000000   1120.000000
# mean       64.107949   8048.623638
# std        32.524512   5534.955850
# min        27.267350   1941.999339
# 25%        40.779500   4068.364442
# 50%        49.768375   6368.810970
# 75%        78.823838  10546.726039
# ...

# %%
ax = apple['average_price'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
corr = apple.corr()

corr
# Out:
#                    open      high       low     close    volume  \
# open           1.000000  0.999749  0.999637  0.999391  0.004542
# high           0.999749  1.000000  0.999555  0.999680  0.013010
# low            0.999637  0.999555  1.000000  0.999683 -0.006325
# close          0.999391  0.999680  0.999683  1.000000  0.002581
# volume         0.004542  0.013010 -0.006325  0.002581  1.000000
# average_price  0.999805  0.999892  0.999885  0.999793  0.003485
# revenue_blns   0.693685  0.700639  0.684663  0.692550  0.656516
#
#                average_price  revenue_blns
# open                0.999805      0.693685
# high                0.999892      0.700639
# low                 0.999885      0.684663
# close               0.999793      0.692550
# volume              0.003485      0.656516
# average_price       1.000000      0.692846
# revenue_blns        0.692846      1.000000

# %%
apple.plot(kind='scatter', x='average_price', y='revenue_blns', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='average_price', ylabel='revenue_blns'>

# %%
boxplot_cols = ['date', 'open', 'high', 'low', 'close', 'volume', 'revenue_blns']

apple[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# open               AxesSubplot(0.125,0.536818;0.227941x0.343182)
# high            AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# low             AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# close                 AxesSubplot(0.125,0.125;0.227941x0.343182)
# volume             AxesSubplot(0.398529,0.125;0.227941x0.343182)
# revenue_blns       AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %%
apple['average_price'].plot(kind='hist', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(14,6), dpi=1000)

plt.plot(apple.date, apple.high, 'r', label ='High price')
plt.plot(apple.date, apple.low, 'y', label ='Low price')
plt.plot(apple.date, apple.average_price, 'g', label ='Average price')
plt.title("Apple stock price dynamics during January 2017-June 2021")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date')
plt.ylabel('Stock price')
plt.legend()
plt.show()
plt.savefig('apple_stock.png' )


plt.show()

# %%
plt.figure(figsize=(14,6), dpi=1000)

plt.plot(apple.average_price, apple.revenue_blns, 'rx', label ='High price')
plt.title("Stock price to revenue during for 2017-2021 yy")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Average stock price')
plt.ylabel('Revenue')
plt.legend()
plt.show()
plt.savefig('apple_stock_revenue.png' )


plt.show()
