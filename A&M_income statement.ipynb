# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd.read_csv('A_Inc.csv')
# Out:
#                           Indicator_IS          amount2020 vertical2020  \
# 0                        total revenue   $274,515,000,000       100.00%
# 1                    (cost of revenue)   $169,559,000,000        61.77%
# 2                         gross profit   $104,956,000,000        38.23%
# 3   Selling general and administrative    $19,916,000,000         7.25%
# 4             Research and development    $18,752,000,000         6.83%
# 5           (total operating expenses)    $38,668,000,000        14.09%
# 6                     operating income    $66,288,000,000        24.15%
# 7       interest income non operating      $3,763,000,000         1.37%
# 8       interest expense non operating     $2,873,000,000         1.05%
# 9    net non operating interest income       $890,000,000         0.32%
# 10  other non operating income expense        $87,000,000         0.03%
# 11                       pretax income    $67,091,000,000        24.44%
# ...

# %%
a_inc=pd.read_csv('A_Inc.csv')
type(a_inc)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('M_Inc.csv')
# Out:
#                           Indicator_IS          amount2020 vertical2020  \
# 0                        total revenue   $143,015,000,000       100.00%
# 1                    (cost of revenue)    $46,078,000,000        32.22%
# 2                         gross profit    $96,937,000,000        67.78%
# 3   Selling general and administrative    $24,709,000,000        17.28%
# 4             Research and development    $19,269,000,000        13.47%
# 5           (total operating expenses)    $43,978,000,000        30.75%
# 6                     operating income    $52,959,000,000        37.03%
# 7       interest income non operating                  NaN          NaN
# 8       interest expense non operating     $2,591,000,000         1.81%
# 9    net non operating interest income    $-2,591,000,000        -1.81%
# 10  other non operating income expense     $2,668,000,000         1.87%
# 11                       pretax income    $53,036,000,000        37.08%
# ...

# %%
m_inc=pd.read_csv('M_Inc.csv')
type(m_inc)
# Out:
# pandas.core.frame.DataFrame
