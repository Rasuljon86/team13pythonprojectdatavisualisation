# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('A_Bal.csv')
# Out:
#                                        Indicator_BS          amount2020  \
# 0                                      Total assets   $323,888,000,000
# 1   cash, cash equivalents & short term investments    $90,943,000,000
# 2                                       receivables    $37,445,000,000
# 3                                         inventory     $4,061,000,000
# 4                              other current assets    $11,264,000,000
# 5                              total current assets   $143,713,000,000
# 6                                           net PPE    $36,766,000,000
# 7              goodwill and other intangible assets               $-
# 8                          investments and advances   $100,887,000,000
# 9                          other non current assets    $42,522,000,000
# 10                         total non current assets   $180,175,000,000
# 11                                              NaN                 NaN
# ...

# %%
apple=pd.read_csv('A_Bal.csv')
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.bar(ypos,revenue)
plt.ylabel('company assets')
plt.title('APPL yearly assets')
plt.bar(ypos,revenue, label= 'assets')
plt.legend()

# %%
pd.read_csv('M_Bal.csv')
# Out:
#                                        Indicator_BS          amount2020  \
# 0                                      Total assets   $301,311,000,000
# 1   cash, cash equivalents & short term investments   $136,527,000,000
# 2                                       receivables    $32,011,000,000
# 3                                         inventory     $1,895,000,000
# 4                              other current assets    $11,482,000,000
# 5                              total current assets   $181,915,000,000
# 6                                           net PPE    $52,904,000,000
# 7              goodwill and other intangible assets    $50,389,000,000
# 8                          investments and advances     $2,965,000,000
# 9                          other non current assets    $13,138,000,000
# 10                         total non current assets   $119,396,000,000
# 11                                              NaN                 NaN
# ...

# %%
microsoft=pd.read_csv('M_Bal.csv')
type(microsoft)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(8,5), dpi=100)

MSFT_total_assets = [323888000, 338516000, 365725000, 375319000]
labels = ['amount2020', 'amount2019', 'amount2018', 'amount2017' ]
explode = [0.1, 0.1, 0.1, 0.1]

plt.pie(apple_total_assets, labels = labels, autopct = '%.2f %%', pctdistance = 0.8, explode = explode)

plt.title('Apple assets amount by year', fontdict = {'fontname': 'Sans Serif', 'fontweight': 'bold', 'fontsize': 16})

plt.show()

plt.figure(figsize=(8,5), dpi=100)

microsoft_total_assets = [301311000, 286556000, 258848000, 241086000]
labels = ['amount2020', 'amount2019', 'amount2018', 'amount2017' ]
explode = [0.1, 0.1, 0.1, 0.1]

plt.pie(microsoft_total_assets, labels = labels, autopct = '%.2f %%', pctdistance = 0.8, explode = explode)

plt.title('Microsoft assets amount by year', fontdict = {'fontname': 'Sans Serif', 'fontweight': 'bold', 'fontsize': 16})

plt.show()
